# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import keras
import tabulate as tb
import numpy as np

gpus = keras.backend._get_available_gpus()

if len(gpus) == 0:
    print("No GPU's Available")
else:
    print(gpus)
# Out:
# No GPU's Available

# %% [markdown]
# ### Read CSV File

# %%
dataset_dir = "Dataset/MovieAll.csv"
df = pd.read_csv(dataset_dir)
df
# Out:
#        Unnamed: 0  movieId  adult belongs_to_collection   budget  \
# 0               1      100  False                   NaN  1350000
# 1               2      100  False                   NaN  1350000
# 2               3      100  False                   NaN  1350000
# 3               4      100  False                   NaN  1350000
# 4               5      100  False                   NaN  1350000
# ...           ...      ...    ...                   ...      ...
# 45037       45038      996  False                   NaN   927262
# 45038       45039      996  False                   NaN   927262
# 45039       45040      996  False                   NaN   927262
# 45040       45041      996  False                   NaN   927262
# 45041       45042    99846  False                   NaN        0
#
#                                                   genres  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1      [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'movieId', 'adult', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'video', 'vote_average', 'vote_count', 'userId', 'rating',
#        'timestamp', 'imdbId', 'tmdbId', 'cast', 'crew', 'keywords',
#        'like_movie'], dtype=object)

# %% [markdown]
# #### Independant Variables for Classifcation:
# * Casting Credits
# * Overview
# * Genre
# * Budget
# * Ratings
# * Collection
# * Original_title
# --------------
# #### Dependant Variable for classification
#
# * liked_movie
# --------------
#
# #### Filtered based on
#
# * UserID

# %%
def get_user_movies(df, user):
    return df[df.userId == user]

# %%
get_user_movies(df,564)
# Out:
#        Unnamed: 0  movieId  adult belongs_to_collection    budget  \
# 48             49     1018  False                   NaN  15000000
# 65             66      102  False                   NaN         0
# 81             82     1023  False                   NaN   3700000
# 88             89     1024  False                   NaN   5000000
# 92             93      103  False                   NaN   1300000
# ...           ...      ...    ...                   ...       ...
# 44880       44881      968  False                   NaN   1800000
# 44952       44953      980  False                   NaN         0
# 44989       44990      988  False                   NaN   5900000
# 44991       44992       99  False                   NaN   8272296
# 44999       45000      991  False                   NaN   1500000
#
#                                                   genres  \
# 48     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# ...
